# %%
class Calcu:
    CALCULATOR= ['''
     __________
| ________ |
||     0FF||
|""""""""""|
|[M|#|C][-]|
|[7|8|9][+]|
|[4|5|6][x]|
|[1|2|3][%]|
|[.|O|:][=]|
"----------" 
''',
'''
 __________
| ________ |
||      0N||
|""""""""""|
|[M|#|C][-]|
|[7|8|9][+]|
|[4|5|6][x]|
|[1|2|3][%]|
|[.|O|:][=]|
"----------" 
''']
    def __init__(self):
        self_is_ON = True
    def multiplicar(self, n1,n2):
        if n1 == '&':
            n1 = resposta
        if n2 == '&':
            n2 = resposta
        n1 = float(n1)
        n2 = float(n2)
        resposta = n1 * n2
        self.display_res(resposta)
    def dividir(self, n1,n2):
        if n1 == '&':
            n1 = resposta
        if n2 == '&':
            n2 = resposta
        n1 = float(n1)
        n2 = float(n2)
        resposta = n1 / n2
        self.display_res(resposta)
    def sumar(self, n1,n2):
        if n1 == '&':
            n1 = resposta
        if n2 == '&':
            n2 = resposta
        n1 = float(n1)
        n2 = float(n2)
        resposta = n1 + n2
        self.display_res(resposta)
    def restar(self, n1,n2):
        if n1 == '&':
            n1 = resposta
        if n2 == '&':
            n2 = resposta
        n1 = float(n1)
        n2 = float(n2)
        resposta = n1 - n2
        self.display_res(resposta)
    def display_res(self,resposta):
        resposta = str(resposta)
        digitos = len(resposta)
        resposta_longo = resposta
        while len(resposta_longo) < 8:
            resposta_longo = ' ' + resposta_longo
        if resposta == 'A':
            print(self.CALCULATOR[0])
            exit
        else:
            print('''
             __________
            | ________ |
            ||{}||
            |""""""""""|
            |[M|#|C][-]|
            |[7|8|9][+]|
            |[4|5|6][x]|
            |[1|2|3][%]|
            |[.|O|:][=]|
            "----------"
            '''.format(resposta_longo))

# %%
calcu = Calcu()
while True:
    n1 = float(input('Escriba el primer numero que operara, o & para usar como numero el reultado'))
    accion = str(input('''
    Que desea hacer?
    [x]Multiplicar
    [/]Dividir
    [+]Sumar
    [-]Restar
    [A]pagar
    '''))
    n2 = float(input('Escriba el primer numero que operara, o & para usar como numero el reultado'))
    if accion == 'M':
        calcu.multiplicar(n1,n2)
    elif accion == 'D':
        calcu.dividir(n1,n2)
    elif accion == 'S':
        calcu.sumar(n1,n2)
    elif accion == 'R':
        calcu.restar(n1,n2)
    elif accion == 'A':
        calcu.display_res('A')
        break
# Out:
#              __________
#             | ________ |
#             ||2.0||
#             |""""""""""|
#             |[M|#|C][-]|
#             |[7|8|9][+]|
#             |[4|5|6][x]|
#             |[1|2|3][%]|
#             |[.|O|:][=]|
#             "----------"
#
#
#      __________
# | ________ |
# ||     0FF||
# |""""""""""|
# |[M|#|C][-]|
# |[7|8|9][+]|
# |[4|5|6][x]|
# |[1|2|3][%]|
# |[.|O|:][=]|
# "----------"
#
#
#      __________
# | ________ |
# ||     0FF||
# |""""""""""|
# |[M|#|C][-]|
# |[7|8|9][+]|
# |[4|5|6][x]|
# |[1|2|3][%]|
# |[.|O|:][=]|
# "----------"
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ...
